# %%
import argparse
import numpy as np
import torch
from pathlib import Path
import polars as pl
# 模块导入

from Model import MultiModalTransformer,MultiModalTransformerV2,MultiModalTransformerV3

from Train.trainer import Trainer
from Train.train_utils import (
    setup_optimizer,
    setup_scheduler,
    setup_loss_functions,
    set_seed
)

from Utils.config_loader import load_config, merge_configs
# Out:
# Warning: mamba-ssm not installed. Use `pip install mamba-ssm` for Mamba models.

# %%
# 设置随机种子
set_seed(42)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"使用设备: {device}")
# Out:
# 使用设备: cuda

# %% [markdown]
# #### LOB TRADE数据预处理
# - 1.补全时间戳，补充成固定100ms间隔的数据
# - 2.生成label

# %%
# from Data_Pipeline.preprocessors.lob_data_process import process_lob_data
# from Data_Pipeline.preprocessors.trade_data_process import process_trade_data
# lob_data_dir = '/root/autodl-tmp/ETHUSDT/20levels_parquet'
# trade_data_dir = '/root/autodl-tmp/ETHUSDT/trade'


# date = ['2025-11-04','2025-11-05','2025-11-06','2025-11-07','2025-11-08','2025-11-09','2025-11-10',
#         '2025-11-11','2025-11-12','2025-11-13','2025-11-14','2025-11-15','2025-11-16','2025-11-17',
#         '2025-11-18','2025-11-19','2025-11-20','2025-11-21','2025-11-22','2025-11-23','2025-11-24',
#         '2025-11-25','2025-11-26','2025-11-27','2025-11-28','2025-11-29','2025-11-30','2025-12-01',
#         '2025-12-02','2025-12-03','2025-12-04','2025-12-05','2025-12-06','2025-12-07',
#         ]
# levels = 10


# lob_data = process_lob_data(data_dir=lob_data_dir,date = date,levels=levels)
# trade_data = process_trade_data(data_dir=trade_data_dir,date = date,window_ms=100)

# lob_data.write_parquet('/root/autodl-tmp/LOB_ETHUSDT_train.parquet')
# trade_data.write_parquet('/root/autodl-tmp/Trade_ETHUSDT_train_agg100ms.parquet')

# %%
# from Data_Pipeline.generators.label_gen import generate_data_dict,generate_ret_labels
# lob_data_path = '/root/autodl-tmp/LOB_ETHUSDT_train.parquet'
# trade_data_path = '/root/autodl-tmp/Trade_ETHUSDT_train_agg100ms.parquet'

# label_window = 3000
# levels = 10
# data_dict,labels_ret = generate_data_dict(lob_data_path,trade_data_path,levels=levels,k=label_window)

# ## 存储为npy格式
# np.save('/root/autodl-tmp/train_data/lob_data.npy',data_dict['lob'])
# np.save('/root/autodl-tmp/train_data/trade_data.npy',data_dict['trade'])
# np.save('/root/autodl-tmp/train_data/labels_ret.npy',labels_ret)

# %% [markdown]
# ## 加载处理好的本地数据

# %%
## 读取
lob_data = np.load('/root/autodl-tmp/train_data/lob_data.npy')
trade_data = np.load('/root/autodl-tmp/train_data/trade_data.npy')
labels_ret = np.load('/root/autodl-tmp/train_data/labels_ret.npy')


print(f"trade_data_agg.shape: {trade_data.shape}")
print(f"lob_data.shape: {lob_data.shape}")
print(f"labels_ret.shape: {labels_ret.shape}")

alpha= 0.001
labels_class = np.ones_like(labels_ret, dtype=np.int8)
# 3. 向量化赋值：涨→2，跌→0
# 涨：labels_ret > alpha
labels_class[labels_ret > alpha] = 2
# 跌：labels_ret < -alpha
labels_class[labels_ret < -alpha] = 0
# Out:
# trade_data_agg.shape: (29369997, 12)
# lob_data.shape: (29369997, 4, 10)
# labels_ret.shape: (29369997,)

# %%
np.unique(labels_class,return_counts=True)[1] / np.unique(labels_class,return_counts=True)[1].sum()
# Out:
# array([0.23764442, 0.53478848, 0.2275671 ])

# %%
pl.Series(labels_ret).abs().describe()
# Out:
# shape: (9, 2)
# ┌────────────┬─────────────┐
# │ statistic  ┆ value       │
# │ ---        ┆ ---         │
# │ str        ┆ f64         │
# ╞════════════╪═════════════╡
# │ count      ┆ 2.9369997e7 │
# │ null_count ┆ 0.0         │
# │ mean       ┆ 0.001352    │
# │ std        ┆ 0.001499    │
# │ min        ┆ 0.0         │
# │ 25%        ┆ 0.000406    │
# │ 50%        ┆ 0.000912    │
# │ 75%        ┆ 0.001769    │
# │ max        ┆ 0.020741    │
# └────────────┴─────────────┘

# %% [markdown]
# ### 加载和保存config

# %%
print("加载配置...")
model_config_path = '/root/lio/Trade_LOB_MultiModal/Configs/model_config.yaml'
train_config_path = '/root/lio/Trade_LOB_MultiModal/Configs/train_config.yaml'
model_config = load_config(model_config_path)
train_config = load_config(train_config_path)

import yaml
model_version = model_config.get('model_version', 'multi_modal_model_1')
print(f"model_version: {model_version}")
config_save_path = f"./checkpoints/{model_version}"
config_save_path = Path(config_save_path)
# 确保保存目录存在
config_save_path.mkdir(exist_ok=True)
## 保存model的config
model_config_save_path = f"{config_save_path}/model_config.yaml"
train_config_save_path = f"{config_save_path}/train_config.yaml"

with open(model_config_save_path, 'w') as f:
    yaml.dump(model_config, f, indent=4, sort_keys=False, allow_unicode=True)
with open(train_config_save_path, 'w') as f:
    yaml.dump(train_config, f, indent=4, sort_keys=False, allow_unicode=True)
# Out:
# 加载配置...
# model_version: multi_modal_model_7

# %% [markdown]
# ### 创建数据集

# %%
all_config = '/root/lio/Trade_LOB_MultiModal/Configs/experiment_config.yaml'
all_config = yaml.load(all_config)

## 创建数据集
from Data_Pipeline.dataset import create_dataloaders
 # 创建 DataLoader
print("创建 DataLoader...")
data_dict = {'lob': lob_data,'trade': trade_data}
train_loader, val_loader = create_dataloaders(
    data_dict=data_dict,
    labels=labels_class,
    returns=labels_ret,
    config=all_config,
    device=device
)

print(f"训练集大小: {len(train_loader.dataset)}")
print(f"验证集大小: {len(val_loader.dataset)}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 all_config = '/root/lio/Trade_LOB_MultiModal/Configs/experiment_config.yaml.yaml'
# ----> 2 all_config = yaml.load(all_config)
#       4 ## 创建数据集
#       5 from Data_Pipeline.dataset import create_dataloaders
#
# TypeError: load() missing 1 required positional argument: 'Loader'

# %%
## 打印train_loader 的第一个
print(next(iter(train_loader))[0]['lob'][0][0][0])
# Out:
# tensor([3072.6899, 3072.7100, 3072.7200, 3072.8000, 3072.8601, 3072.8701,
#         3072.9600, 3072.9800, 3072.9900, 3073.0000], device='cuda:0')

# %%
# for inputs,labels,returns in train_loader:
#     print(inputs['lob'].shape,inputs['trade'].shape)
#     break

# %% [markdown]
# ### 模型创建

# %% [markdown]
# ##### 1.多模态模型

# %%
# 创建模型
print("创建模型...")

from Model import MultiModalTransformer
# 根据数据情况调整配置
lob_config = model_config.get('lob_encoder', {})
trade_config = model_config.get('trade_encoder') if 'trade' in data_dict else None
fusion_config = model_config.get('fusion', {})
transformer_config = model_config.get('transformer', {})
output_config = model_config.get('output_head', {})

model = MultiModalTransformer(
    lob_config=lob_config,
    trade_config=trade_config,
    fusion_config=fusion_config,
    transformer_config=transformer_config,
    output_config=output_config,
    use_revin=True
)
# Out:
# 创建模型...

# %%
trade_config
# Out:
# {'in_features': 12,
#  'hidden_channels': [32, 32, 32],
#  'kernel_size': [5, 5, 2],
#  'time_stride': [5, 5, 2],
#  'dropout': 0.1}

# %%
import torch
import torch.nn as nn
from torchinfo import summary
# 3. 构造输入张量（维度需匹配配置）
batch_size = 2
time_steps = 3000  # LOB/Trade的时间步必须一致
lob_input = torch.randn(batch_size, 4, time_steps, 10,device=device)  # (B,C,T,L) = (2,4,10,20)
trade_input = torch.randn(batch_size, 12, time_steps,device=device)    # (B,F,T) = (2,26,10)

# 4. 封装模型：将字典输入转为位置参数（适配torchinfo）
class WrappedMultiModalModel(nn.Module):
    def __init__(self, original_model):
        super().__init__()
        self.original_model = original_model
    
    def forward(self, lob, trade):
        # 构造模型需要的字典输入
        inputs = {"lob": lob,"trade":trade}
        return self.original_model(inputs)

# inputs = {'lob': lob_input}
# with torch.no_grad():
#     model(inputs)  # 这一步后，self.fusion 不再是 None
wrapped_model = WrappedMultiModalModel(model)

# 5. 调用summary（核心：传入输入张量列表，顺序匹配封装模型的forward参数）
summary(
    wrapped_model,
    input_data=[lob_input, trade_input],  # 先lob，后trade
    col_names=["input_size", "output_size", "num_params", "trainable"],
    col_width=20,
    depth=5,  # 显示模型深度（层数）
    device="cuda"  # 若用GPU，改为"cuda"（需确保张量在GPU上）
)
# Out:
# =======================================================================================================================================
# Layer (type:depth-idx)                                  Input Shape          Output Shape         Param #              Trainable
# =======================================================================================================================================
# WrappedMultiModalModel                                  [2, 4, 3000, 10]     [2, 3]               --                   True
# ├─MultiModalTransformer: 1-1                            [2, 4, 3000, 10]     [2, 3]               --                   True
# │    └─RevIN: 2-1                                       [2, 11, 3000]        [2, 11, 3000]        22                   True
# │    └─LOBEncoder: 2-2                                  [2, 4, 3000, 10]     [2, 60, 32]          --                   True
# │    │    └─GroupNorm: 3-1                              [2, 4, 3000, 10]     [2, 4, 3000, 10]     8                    True
# │    │    └─ModuleList: 3-2                             --                   --                   --                   True
# │    │    │    └─CausalDownsamplingBlock: 4-1           [2, 4, 3000, 10]     [2, 32, 600, 5]      --                   True
# │    │    │    │    └─Sequential: 5-1                   [2, 4, 3000, 10]     [2, 32, 3000, 5]     352                  True
# │    │    │    │    └─CausalConv2d: 5-2                 [2, 32, 3000, 5]     [2, 32, 600, 5]      3,104                True
# │    │    │    │    └─GroupNorm: 5-3                    [2, 32, 600, 5]      [2, 32, 600, 5]      64                   True
# │    │    │    │    └─LeakyReLU: 5-4                    [2, 32, 600, 5]      [2, 32, 600, 5]      --                   --
# │    │    │    │    └─Dropout2d: 5-5                    [2, 32, 600, 5]      [2, 32, 600, 5]      --                   --
# │    │    │    └─CausalDownsamplingBlock: 4-2           [2, 32, 600, 5]      [2, 32, 120, 2]      --                   True
# │    │    │    │    └─Sequential: 5-6                   [2, 32, 600, 5]      [2, 32, 600, 2]      2,144                True
# │    │    │    │    └─CausalConv2d: 5-7                 [2, 32, 600, 2]      [2, 32, 120, 2]      3,104                True
# │    │    │    │    └─GroupNorm: 5-8                    [2, 32, 120, 2]      [2, 32, 120, 2]      64                   True
# │    │    │    │    └─LeakyReLU: 5-9                    [2, 32, 120, 2]      [2, 32, 120, 2]      --                   --
# │    │    │    │    └─Dropout2d: 5-10                   [2, 32, 120, 2]      [2, 32, 120, 2]      --                   --
# │    │    │    └─CausalDownsamplingBlock: 4-3           [2, 32, 120, 2]      [2, 32, 60, 1]       --                   True
# │    │    │    │    └─Sequential: 5-11                  [2, 32, 120, 2]      [2, 32, 120, 1]      2,144                True
# │    │    │    │    └─CausalConv2d: 5-12                [2, 32, 120, 1]      [2, 32, 60, 1]       3,104                True
# │    │    │    │    └─GroupNorm: 5-13                   [2, 32, 60, 1]       [2, 32, 60, 1]       64                   True
# │    │    │    │    └─LeakyReLU: 5-14                   [2, 32, 60, 1]       [2, 32, 60, 1]       --                   --
# │    │    │    │    └─Dropout2d: 5-15                   [2, 32, 60, 1]       [2, 32, 60, 1]       --                   --
# │    └─TradeEncoder: 2-3                                [2, 12, 3000]        [2, 60, 32]          --                   True
# │    │    └─Sequential: 3-3                             [2, 12, 3000]        [2, 32, 60]          --                   True
# │    │    │    └─CausalConv1d: 4-4                      [2, 12, 3000]        [2, 32, 600]         --                   True
# │    │    │    │    └─Conv1d: 5-16                      [2, 12, 3004]        [2, 32, 600]         1,952                True
# │    │    │    └─GroupNorm: 4-5                         [2, 32, 600]         [2, 32, 600]         64                   True
# │    │    │    └─ReLU: 4-6                              [2, 32, 600]         [2, 32, 600]         --                   --
# │    │    │    └─Dropout: 4-7                           [2, 32, 600]         [2, 32, 600]         --                   --
# │    │    │    └─CausalConv1d: 4-8                      [2, 32, 600]         [2, 32, 120]         --                   True
# │    │    │    │    └─Conv1d: 5-17                      [2, 32, 604]         [2, 32, 120]         5,152                True
# │    │    │    └─GroupNorm: 4-9                         [2, 32, 120]         [2, 32, 120]         64                   True
# │    │    │    └─ReLU: 4-10                             [2, 32, 120]         [2, 32, 120]         --                   --
# │    │    │    └─Dropout: 4-11                          [2, 32, 120]         [2, 32, 120]         --                   --
# │    │    │    └─CausalConv1d: 4-12                     [2, 32, 120]         [2, 32, 60]          --                   True
# │    │    │    │    └─Conv1d: 5-18                      [2, 32, 121]         [2, 32, 60]          2,080                True
# │    │    │    └─GroupNorm: 4-13                        [2, 32, 60]          [2, 32, 60]          64                   True
# │    │    │    └─ReLU: 4-14                             [2, 32, 60]          [2, 32, 60]          --                   --
# │    │    │    └─Dropout: 4-15                          [2, 32, 60]          [2, 32, 60]          --                   --
# │    └─FeatureFusion: 2-4                               [2, 60, 32]          [2, 60, 32]          --                   True
# │    │    └─GatedFusion: 3-4                            [2, 60, 32]          [2, 60, 32]          --                   True
# │    │    │    └─ModuleDict: 4-16                       --                   --                   --                   True
# │    │    │    │    └─Linear: 5-19                      [2, 60, 32]          [2, 60, 32]          1,056                True
# │    │    │    │    └─Linear: 5-20                      [2, 60, 32]          [2, 60, 32]          1,056                True
# │    │    │    └─Sequential: 4-17                       [2, 60, 64]          [2, 60, 2]           --                   True
# │    │    │    │    └─Linear: 5-21                      [2, 60, 64]          [2, 60, 32]          2,080                True
# │    │    │    │    └─ReLU: 5-22                        [2, 60, 32]          [2, 60, 32]          --                   --
# │    │    │    │    └─Linear: 5-23                      [2, 60, 32]          [2, 60, 2]           66                   True
# │    │    │    │    └─Softmax: 5-24                     [2, 60, 2]           [2, 60, 2]           --                   --
# │    │    │    └─Identity: 4-18                         [2, 60, 32]          [2, 60, 32]          --                   --
# │    └─TransformerBackbone: 2-5                         [2, 60, 32]          [2, 60, 32]          --                   True
# │    │    └─PositionalEncoding: 3-5                     [2, 60, 32]          [2, 60, 32]          --                   --
# │    │    │    └─Dropout: 4-19                          [2, 60, 32]          [2, 60, 32]          --                   --
# │    │    └─TransformerEncoder: 3-6                     [2, 60, 32]          [2, 60, 32]          --                   True
# │    │    │    └─ModuleList: 4-20                       --                   --                   --                   True
# │    │    │    │    └─TransformerEncoderLayer: 5-25     [2, 60, 32]          [2, 60, 32]          12,704               True
# │    └─Linear: 2-6                                      [2, 32]              [2, 3]               99                   True
# =======================================================================================================================================
# Total params: 40,611
# Trainable params: 40,611
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 38.47
# =======================================================================================================================================
# Input size (MB): 1.25
# Forward/backward pass size (MB): 23.65
# Params size (MB): 0.15
# Estimated Total Size (MB): 25.04
# =======================================================================================================================================

# %%
# 打印模型信息
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"模型参数量: {total_params:,} (可训练: {trainable_params:,})")
# Out:
# 模型参数量: 40,611 (可训练: 40,611)

# %% [markdown]
# ### 训练

# %%
# import os
# import torch

# # ===================== 日志关闭核心代码 (所有PyTorch版本通用) =====================
# # 关闭 torch.compile 的 AUTOTUNE 满屏刷屏日志 (重中之重)
# os.environ['TORCHINDUCTOR_PRINT_CONFIG'] = '0'
# os.environ['TORCHINDUCTOR_VERBOSE'] = '0'
# os.environ['TORCHINDUCTOR_AUTOTUNE_LOG'] = '0'
# # 关闭PyTorch编译器的所有警告/错误日志输出
# os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
# os.environ['TORCH_LOGS'] = '0'

# #'default'  , 'max-autotune'  , 'reduce-overhead'
# print("Compiling model...")
# model = torch.compile(model, mode='reduce-overhead')

# %%
from Train.trainer import Trainer
from Train.train_utils import (
    setup_optimizer,
    setup_scheduler,
    setup_loss_functions,
    set_seed
)
# 设置优化器和调度器
optimizer = setup_optimizer(model, train_config.get('optimizer', {}))
scheduler = setup_scheduler(optimizer, train_config.get('scheduler', {}))

# 设置损失函数
loss_fn = setup_loss_functions(train_config.get('loss', {}), device=device)

# %%
# 创建训练器
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    loss_fn=loss_fn,
    optimizer=optimizer,
    scheduler=scheduler,
    config=train_config,
    device=device
)

# 开始训练
print("=" * 50)
history = trainer.fit()

print("=" * 50)
print("训练完成!")
print(f"最佳验证 F1 (Up/Down): {max(history['val_f1_updown']):.4f}")
# Out:
# ==================================================
# 开始训练，共 50 个 epoch
# 设备: cuda
# AMP: True
# 梯度累积步数: 1
# --------------------------------------------------
# Training:   0%|          | 0/2294 [00:00<?, ?it/s]
# Epoch 1/50 (166.7s)
#   Train Loss: 0.3183, Train Acc: 0.6302
#   Val Loss: 0.2608, Val Acc: 0.6947
#   Val F1 (Macro): 0.6208
#   Val Precision (Up/Down): 0.5842, Recall (Up/Down): 0.5090, F1 (Up/Down): 0.5440
#   [NEW BEST] Loss: 0.2608
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 15
#      13 # 开始训练
#      14 print("=" * 50)
# ---> 15 history = trainer.fit()
#      17 print("=" * 50)
#      18 print("训练完成!")
#
# File ~/lio/Trade_LOB_MultiModal/Train/trainer.py:252, in Trainer.fit(self)
#     249 epoch_start = time.time()
#     251 # 训练
# --> 252 train_loss, train_acc = self.train_epoch()
#     254 # 验证
#     255 val_metrics = self.validate()
#
# File ~/lio/Trade_LOB_MultiModal/Train/trainer.py:142, in Trainer.train_epoch(self)
#     140 # 前向传播
#     141 with autocast(device_type='cuda', enabled=self.use_amp):
# --> 142     cls_pred, reg_pred = self.model(inputs)
#     143     losses = self.loss_fn(cls_pred, labels, reg_pred, returns)
#     144     loss = losses['total'] / self.grad_accumulation_steps
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/lio/Trade_LOB_MultiModal/Model/multi_modal_transformer.py:222, in MultiModalTransformer.forward(self, inputs)
#     219 fused = self.fusion(encoded)  # (B, T, d_model)
#     221 # 4. Transformer
# --> 222 output = self.transformer(fused, causal=True)  # (B, T, d_model)
#     224 # 5. 池化
#     225 pooled = self._pool_output(output)  # (B, d_model)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/lio/Trade_LOB_MultiModal/Model/backbones/transformer.py:159, in TransformerBackbone.forward(self, x, causal, src_key_padding_mask)
#     156     mask = None
#     158 # 3. Transformer Encoding
# --> 159 output = self.transformer_encoder(
#     160     x,
#     161     mask=mask,
#     162     # src_key_padding_mask=src_key_padding_mask
#     163 )
#     165 # 4. Final Norm
#     166 # output = self.final_norm(output)
#     168 return output
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/transformer.py:521, in TransformerEncoder.forward(self, src, mask, src_key_padding_mask, is_causal)
#     518         src_key_padding_mask_for_layers = None
#     520 seq_len = _get_seq_len(src, batch_first)
# --> 521 is_causal = _detect_is_causal_mask(mask, is_causal, seq_len)
#     523 for mod in self.layers:
#     524     output = mod(
#     525         output,
#     526         src_mask=mask,
#     527         is_causal=is_causal,
#     528         src_key_padding_mask=src_key_padding_mask_for_layers,
#     529     )
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/transformer.py:1230, in _detect_is_causal_mask(mask, is_causal, size)
#    1227 # Do not use `torch.equal` so we handle batched masks by
#    1228 # broadcasting the comparison.
#    1229 if mask.size() == causal_comparison.size():
# -> 1230     make_causal = bool((mask == causal_comparison).all())
#    1231 else:
#    1232     make_causal = False
#
# KeyboardInterrupt:
